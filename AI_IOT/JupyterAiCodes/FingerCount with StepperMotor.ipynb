# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /home/gott/openvino_env/lib/python3.12/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /home/gott/openvino_env/lib/python3.12/site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in /home/gott/openvino_env/lib/python3.12/site-packages (0.10.21)
# Requirement already satisfied: absl-py in /home/gott/openvino_env/lib/python3.12/site-packages (from mediapipe) (2.2.2)
# Requirement already satisfied: attrs>=19.1.0 in /home/gott/openvino_env/lib/python3.12/site-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/gott/openvino_env/lib/python3.12/site-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in /home/gott/openvino_env/lib/python3.12/site-packages (from mediapipe) (0.6.0)
# Requirement already satisfied: jaxlib in /home/gott/openvino_env/lib/python3.12/site-packages (from mediapipe) (0.6.0)
# Requirement already satisfied: matplotlib in /home/gott/openvino_env/lib/python3.12/site-packages (from mediapipe) (3.10.1)
# Requirement already satisfied: numpy<2 in /home/gott/openvino_env/lib/python3.12/site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /home/gott/openvino_env/lib/python3.12/site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /home/gott/openvino_env/lib/python3.12/site-packages (from mediapipe) (4.25.7)
# Requirement already satisfied: sounddevice>=0.4.4 in /home/gott/openvino_env/lib/python3.12/site-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: sentencepiece in /home/gott/openvino_env/lib/python3.12/site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /home/gott/openvino_env/lib/python3.12/site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: pycparser in /home/gott/openvino_env/lib/python3.12/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /home/gott/openvino_env/lib/python3.12/site-packages (from jax->mediapipe) (0.5.1)
# Requirement already satisfied: opt_einsum in /home/gott/openvino_env/lib/python3.12/site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.11.1 in /home/gott/openvino_env/lib/python3.12/site-packages (from jax->mediapipe) (1.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gott/openvino_env/lib/python3.12/site-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/gott/openvino_env/lib/python3.12/site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gott/openvino_env/lib/python3.12/site-packages (from matplotlib->mediapipe) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/gott/openvino_env/lib/python3.12/site-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/gott/openvino_env/lib/python3.12/site-packages (from matplotlib->mediapipe) (25.0)
# Requirement already satisfied: pillow>=8 in /home/gott/openvino_env/lib/python3.12/site-packages (from matplotlib->mediapipe) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/gott/openvino_env/lib/python3.12/site-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gott/openvino_env/lib/python3.12/site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/gott/openvino_env/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyserial
# Out:
# Requirement already satisfied: pyserial in /home/gott/openvino_env/lib/python3.12/site-packages (3.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import serial 
import time 

ser = serial.Serial('/dev/ttyUSB0',baudrate=115200,bytesize =8, parity ='N', stopbits =1)
hex = '3A0100020003000400'
#hex = '3A0101020103010401'

data_send = bytes.fromhex(hex)
ser.write(data_send)

ser.close()

# %% [markdown]
# # Original code

# %%
import cv2
import mediapipe as mp
import threading
import serial
import time
import numpy as np  # For smoothing detection with history buffer
import signal  # For handling Ctrl+C interruptions

# Initialize serial communication with error handling
try:
    ser = serial.Serial('/dev/ttyUSB0', 115200, timeout=1)  # Add timeout for safety
except serial.SerialException as e:
    print(f"Error: {e}")
    exit(1)

# Initialize webcam with error check
webcam = cv2.VideoCapture(2)
if not webcam.isOpened():
    print("Error: Could not open webcam.")
    exit(1)

# Initialize Mediapipe hands module
mpHands = mp.solutions.hands
hands = mpHands.Hands(static_image_mode=False, max_num_hands=1,
                      min_detection_confidence=0.8, min_tracking_confidence=0.7)
mpDraw = mp.solutions.drawing_utils

# Global variables for state tracking
last_finger_count = -1  # Store last detected finger count
finger_history = []  # Buffer to store recent counts for smoothing
cooldown_lock = threading.Lock()  # Lock to prevent race conditions
motor_running = False  # Track whether the motor is currently running

# ========== Helper Functions ==========
def stop_motor():
    """Sends the stop command to the motor."""
    try:
        ser.write(bytes.fromhex('3A01000200'))  # Stop command (Hex)
        print("Motor stopped safely.")
    except serial.SerialException as e:
        print(f"Error sending stop command: {e}")

def send_command(command, duration):
    """Send a motor command and hold it for 'duration' seconds."""
    global motor_running
    motor_running = True  # Mark motor as running

    with cooldown_lock:
        try:
            print(f"Sending command: {command}, holding for {duration} seconds.")
            ser.write(bytes.fromhex(command))  # Send command to motor
            time.sleep(duration)  # Hold for the specified duration
            stop_motor()  # Stop motor after the command
        except serial.SerialException as e:
            print(f"Error sending motor command: {e}")

    motor_running = False  # Mark motor as stopped

def smooth_finger_count(current_count, max_history=5):
    """Smooth the finger count by taking the most frequent (mode) count."""
    finger_history.append(current_count)
    if len(finger_history) > max_history:
        finger_history.pop(0)  # Keep only the last 'max_history' counts

    # Return the most common count from the history buffer (mode)
    return int(np.bincount(finger_history).argmax())

def signal_handler(sig, frame):
    """Handle Ctrl+C interruption and release resources safely."""
    print("Program interrupted! Stopping motor and releasing resources...")
    stop_motor()
    cleanup()
    exit(0)

def cleanup():
    """Release resources gracefully."""
    print("Releasing resources...")
    webcam.release()
    ser.close()
    cv2.destroyAllWindows()
    print("Resources released. Exiting.")

# Register the signal handler for safe termination on Ctrl+C
signal.signal(signal.SIGINT, signal_handler)

# ========== Helper Function for Hand Orientation ==========
def is_palm_facing(lm_list):
    wrist_y = lm_list[0][2]  # y-coordinate of wrist
    base_finger_y = lm_list[9][2]  # y-coordinate of the middle finger base
    return wrist_y < base_finger_y  # Palm facing if wrist is below the base of the fingers

# ========== Updated Finger Counting Logic ==========
def finger_counting(imageFrame):
    """Detect extended fingers and count them accurately."""
    global last_finger_count

    # Convert frame to RGB (Mediapipe requires RGB input)
    imgRGB = cv2.cvtColor(imageFrame, cv2.COLOR_BGR2RGB)

    # Process the frame with Mediapipe hands
    results = hands.process(imgRGB)

    # Initialize finger count
    finger_count = 0

    # If hands are detected
    if results.multi_hand_landmarks:
        for hand_landmark, hand_info in zip(results.multi_hand_landmarks, results.multi_handedness):
            # Get hand label (Left or Right)
            hand_label = hand_info.classification[0].label
            fingers = [False] * 5  # Initialize a list to track each finger
            lm_list = []

            # Extract landmark positions
            for id, lm in enumerate(hand_landmark.landmark):
                h, w, _ = imageFrame.shape
                cx, cy = int(lm.x * w), int(lm.y * h)
                lm_list.append([id, cx, cy])


            # Determine hand orientation (palm facing or back of hand facing)
            palm_facing = is_palm_facing(lm_list)

            if palm_facing:
                # Palm facing: regular finger checking logic
                if hand_label == "Right":
                    # For the right hand, thumb tip should be on the right side of the IP joint
                    if lm_list[4][1] > lm_list[3][1]:  # Thumb
                        fingers[0] = True
                else:  # Left hand
                    # For the left hand, thumb tip should be on the left side of the IP joint
                    if lm_list[4][1] < lm_list[3][1]:  # Thumb
                        fingers[0] = True
            else:
                # Back of hand facing: reversed logic for thumb
                if hand_label == "Right":
                    # For the right hand, thumb tip should be on the left side of the IP joint
                    if lm_list[4][1] < lm_list[3][1]:  # Thumb
                        fingers[0] = True
                else:  # Left hand
                    # For the left hand, thumb tip should be on the right side of the IP joint
                    if lm_list[4][1] > lm_list[3][1]:  # Thumb
                        fingers[0] = True

            # Check each finger's state (extended or folded)
            if lm_list[8][2] < lm_list[7][2]:  # Index finger
                fingers[1] = True
            if lm_list[12][2] < lm_list[11][2]:  # Middle finger
                fingers[2] = True
            if lm_list[16][2] < lm_list[15][2]:  # Ring finger
                fingers[3] = True
            if lm_list[20][2] < lm_list[19][2]:  # Little finger
                fingers[4] = True

            # Count how many fingers are extended
            finger_count = sum(fingers)

            # Draw landmarks
            mpDraw.draw_landmarks(imageFrame, hand_landmark, mpHands.HAND_CONNECTIONS)

    # Display finger count
    cv2.putText(imageFrame, f"Finger Count: {finger_count}", (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 98), 3)

    # Smooth the count and send commands accordingly
    finger_count = smooth_finger_count(finger_count)

    if finger_count != last_finger_count:
        last_finger_count = finger_count

        # Define motor commands for each count
        command_map = {
            5: ('3A01010200', 5),
            4: ('3A01010200', 4),
            3: ('3A01010200', 3),
            2: ('3A01010200', 2),
            1: ('3A01010200', 1),
            0: ('3A01000200', 0)
        }

        if finger_count in command_map:
            command, duration = command_map[finger_count]
            threading.Thread(target=send_command, args=(command, duration)).start()

# ========== Main Program Loop ==========
try:
    while True:
        ret, imageFrame = webcam.read()
        if not ret:
            print("Error: Failed to read frame.")
            break

        finger_counting(imageFrame)
        cv2.imshow("Hand Gesture Finger Count", imageFrame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
finally:
    stop_motor()
    cleanup()
# Out:
# 2025-09-01 13:41:13.982662: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-01 13:41:13.983164: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-09-01 13:41:13.985417: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-09-01 13:41:13.991152: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756714274.000589    4265 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756714274.003312    4265 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1756714274.010687    4265 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756714274.010702    4265 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756714274.010703    4265 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756714274.010704    4265 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-01 13:41:14.014545: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1756714276.370439    4265 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1756714276.374390   12313 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) Arc(tm) Graphics (MTL)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1756714276.400072   12290 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1756714276.414190   12291 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Sending command: 3A01000200, holding for 0 seconds.
# Motor stopped safely.
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# W0000 00:00:1756714278.013615   12307 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# Sending command: 3A01010200, holding for 1 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 2 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 3 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 4 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 1 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 4 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 2 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 1 seconds.
# Motor stopped safely.
# Sending command: 3A01000200, holding for 0 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 1 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 2 seconds.
# Motor stopped safely.
# Sending command: 3A01000200, holding for 0 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 3 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 4 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 3 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 4 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 3 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 2 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 4 seconds.
# Motor stopped safely.
# Sending command: 3A01000200, holding for 0 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 4 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 5 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 4 seconds.
# Motor stopped safely.
# Sending command: 3A01010200, holding for 5 seconds.
# Program interrupted! Stopping motor and releasing resources...
# Motor stopped safely.
# Releasing resources...
# Resources released. Exiting.
# Error: Failed to read frame.
# Error sending stop command: Attempting to use a port that is not open
# Releasing resources...
# Resources released. Exiting.
